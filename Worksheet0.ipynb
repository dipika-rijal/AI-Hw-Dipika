# %%
#7 TO - DO - Task
#Task1
#Daily time (in hours): [study, entertainment, sleep]
time_data = [
(3.5, 2.0, 7.0), (5.0, 1.5, 6.5), (2.5, 3.0, 8.0),
(4.0, 2.0, 6.0), (1.5, 4.5, 9.0), (3.0, 2.5, 7.5),
(5.5, 1.0, 6.0), (2.0, 3.5, 8.5), (4.5, 2.0, 7.0),
(3.0, 3.0, 7.5), (6.0, 1.5, 6.0), (2.5, 4.0, 8.0),
(4.0, 2.5, 7.0), (5.0, 2.0, 6.5), (3.5, 2.5, 7.0)
]
#1. Create empty lists for study time classifications:
#(a) Low: less than 3 hours.
#(b) Moderate: between 3 and 5 hours.
#(c) High: more than 5 hours.
    
low = []
moderate = []
high = []

#2. Iterate over the time_data list and add each study hour to the appropriate category.
for i in time_data:
    if i[0] < 3:
        low.append(i)
    elif 3 <= i[0] < 5:
        moderate.append(i)
    else:
        high.append(i)
        
#3. Print the lists to verify the classifications.
print("The study time less than 3 hours:",low)
print("The study time between 3 and 5 hours:",moderate)
print("The study time more than 5 hours:", high)
# Out:
# The study time less than 3 hours: [(2.5, 3.0, 8.0), (1.5, 4.5, 9.0), (2.0, 3.5, 8.5), (2.5, 4.0, 8.0)]
# The study time between 3 and 5 hours: [(3.5, 2.0, 7.0), (4.0, 2.0, 6.0), (3.0, 2.5, 7.5), (4.5, 2.0, 7.0), (3.0, 3.0, 7.5), (4.0, 2.5, 7.0), (3.5, 2.5, 7.0)]
# The study time more than 5 hours: [(5.0, 1.5, 6.5), (5.5, 1.0, 6.0), (6.0, 1.5, 6.0), (5.0, 2.0, 6.5)]

# %%
#Task2
#1. How many days had low study time?
(a) Hint: Count the number of items in the low study list and print the result.
low_study_time = len(low)

#2. How many days had moderate study time?
moderate_study_time = len(moderate)

#3. How many days had high study time?
high_study_time = len(high)


print("The number of days that had low study time is:", len(low))
print("The number of days that had moderate study time is:", len(moderate))
print("The number of days that had high study time is:", len(high))
# Out:
# The number of days that had low study time is: 4
# The number of days that had moderate study time is: 7
# The number of days that had high study time is: 4

# %%
#Task3
#Convert Study Hours to Minutes:
#convert each study hour value into minutes and store it in a new list called study_minutes.

#Formula: Minutes = Hours × 60

# 1. Iterate over the time_data list and apply the formula to the study hours.
# 2. Store the results in the new list.
# 3. Print the converted values.

study_minutes =[]
for i in time_data:
    study_minutes.append(i[0]*60)
print(study_minutes)
# Out:
# [210.0, 300.0, 150.0, 240.0, 90.0, 180.0, 330.0, 120.0, 270.0, 180.0, 360.0, 150.0, 240.0, 300.0, 210.0]

# %%
# Task 4. Analyze Average Time Use:
# Scenario: Each record contains daily hours of study, entertainment, and sleep.
# 1. Create empty lists for study_hours, entertainment_hours, and sleep_hours.
# 2. Iterate over time_data and extract values into each list.
# 3. Calculate and print:
# (a) Average hours spent studying.
# (b) Average hours spent on entertainment.
# (c) Average hours spent sleeping.


study_hours =[]
entertainment_hours =[]
sleep_hours = []

for i in time_data:
    study_hours.append(i[0])
    entertainment_hours.append(i[1])
    sleep_hours.append(i[2])

print("The average hours spent studying is:", (sum(study_hours)/len(study_hours)))
print("The average hours spent on entertainment is:", (sum(entertainment_hours)/len(entertainment_hours)))
print("The average hours spent sleeping is:", (sum(sleep_hours)/len(sleep_hours)))
# Out:
# The average hours spent studying is: 3.7
# The average hours spent on entertainment is: 2.5
# The average hours spent sleeping is: 7.166666666666667

# %%
# Task 5. Visualization - Study vs Sleep Pattern:
# 1. Import matplotlib.pyplot as plt.
# 2. Plot a scatter plot with:
# • x-axis: Study hours
# • y-axis: Sleep hours
#  3. Add labels, title, and color.



import matplotlib.pyplot as plt
plt.scatter(study_hours, sleep_hours, color="blue")
plt.xlabel("StudyHours")
plt.ylabel("SleepHours")
plt.title("study hours and sleep hours ")
plt.show()

# %%
#8 7 TO - DO - Task
# #Task 1 - Sum of Nested Lists:
# Scenario: You have a list that contains numbers and other lists of numbers (nested lists).
# You want to find the total sum of all the numbers in this structure.
# Task:
# • Write a recursive function sum_nested_list(nested_list) that:
# 1. Takes a nested list (a list that can contain numbers or other lists of numbers) as
# input.
# 2. Sums all numbers at every depth level of the list, regardless of how deeply nested
# the numbers are.
# • Test the function with a sample nested list, such as
# nested_list = [1, [2, [3, 4], 5], 6, [7, 8]].
# The result should be the total sum of all the numbers.


nested_list = [1, [2, [3, 4], 5], 6, [7, 8]]
def sum_nested_list(nested_list):
    total = 0
    for element in nested_list:
        if isinstance(element,list): # Check if the element is a list
            total += sum_nested_list(element) # Recursively sum the nested lis
        else:
            total += element # Add the number to the total
    return total

print("sum nested list is:", sum_nested_list(nested_list))
# Out:
# sum nested list is: 36

# %%
# Task 2 - Generate All Permutations of a String:
# Scenario: Given a string, generate all possible permutations of its characters. This is useful
# for understanding backtracking and recursive depth-first search.
# Task:
# • Write a recursive function generate_permutations(s) that:
# – Takes a string s as input and returns a list of all unique permutations.
# • Test with strings like ”abc” and ”aab”.

# print(generate_permutations("abc"))
# # Should return [’abc’, ’acb’, ’bac’, ’bca’, ’cab’, ’cba’]



def generate_permutations(s):
    """
    Generate all possible permutations of a string using recursion.
    
    Args:
        s (str): Input string
    
    Returns:
        list: List of all unique permutations
    """
    # Base case: if string has only 1 character, return it as single permutation
    if len(s) == 1:
        return [s]
    
    # List to store all permutations
    all_permutations = []
    
    # Loop through each character in the string
    for i in range(len(s)):
        # Fix the current character as the first character
        current_char = s[i]
        
        # Get the remaining characters (all characters except the current one)
        remaining_chars = s[:i] + s[i+1:]
        
        # Recursively get all permutations of the remaining characters
        for perm in generate_permutations(remaining_chars):
            # Combine the fixed character with each permutation of remaining characters
            all_permutations.append(current_char + perm)
    
    return all_permutations

# %%
# 8.1.1 task 2
# Generate All Permutations of a String:
# Scenario: Given a string, generate all possible permutations of its characters. This is useful
# for understanding backtracking and recursive depth-first search.
# Task:
# • Write a recursive function generate_permutations(s) that:
# – Takes a string s as input and returns a list of all unique permutations.
# • Test with strings like ”abc” and ”aab”.
# print(generate_permutations("abc"))
# # Should return [’abc’, ’acb’, ’bac’, ’bca’, ’cab’, ’cba’]


def generate_permutations(s):
    if len(s) <= 1:
        return [s]
    
    perms = []
    for i, char in enumerate(s):
        
        remaining = s[:i] + s[i+1:]
        
        for p in generate_permutations(remaining):
            perms.append(char + p)
    
    return perms

print(generate_permutations("abc"))
# Out:
# ['abc', 'acb', 'bac', 'bca', 'cab', 'cba']

# %%
#8.1.1 Task-3

# 1. Write a recursive function calculate_directory_size(directory) where:
# • directory is a dictionary where keys represent file names (with values as sizes in
# KB) or directory names (with values as another dictionary representing a subdirectory).
# • The function should return the total size of the directory, including all nested
# subdirectories.
# 2. Test the function with a sample directory structure.



directory_structure = {
    "file1.txt": 200,
    "file2.txt": 300,
    "subdir1": {
        "file3.txt": 400,
        "file4.txt": 100
    },
    "subdir2": {
        "subsubdir1": {
            "file5.txt": 250
        },
        "file6.txt": 150
    }
}

def calculate_directory_size(directory):
    total_size = 0
    for key, value in directory.items():
        if isinstance(value, dict):
            total_size += calculate_directory_size(value)
        else:
            total_size += value
    return total_size


total = calculate_directory_size(directory_structure)
print(f"Total directory size: {total} KB")
# Out:
# Total directory size: 1400 KB

# %%
# 8.2.1 
# Task 2 - Longest Common Subsequence (LCS):
# Scenario: Given two strings, find the length of their longest common subsequence (LCS).
# This is useful in text comparison.
# Task:
# 1. Write a function longest_common_subsequence(s1, s2) that:
# • Uses DP to find the length of the LCS of two strings s1 and s2.
# 2. Test with strings like "abcde" and "ace"; the LCS length should be 3 ("ace").


def longest_common_subsequence(s1, s2):
    m, n = len(s1), len(s2)
    dp = [[0]*(n+1) for _ in range(m+1)]

    for i in range(1, m+1):
        for j in range(1, n+1):
            if s1[i-1] == s2[j-1]:
                dp[i][j] = dp[i-1][j-1] + 1
            else:
                dp[i][j] = max(dp[i-1][j], dp[i][j-1])
    i, j = m, n
    lcs_str = ""
    while i > 0 and j > 0:
        if s1[i-1] == s2[j-1]:
            lcs_str = s1[i-1] + lcs_str
            i -= 1
            j -= 1
        elif dp[i-1][j] > dp[i][j-1]:
            i -= 1
        else:
            j -= 1
    print("LCS:", lcs_str)
    print("LCS length:", dp[m][n])
longest_common_subsequence("what's up", "water")
# Out:
# LCS: wat
# LCS length: 3

# %%
# 8.2.1 Exercises - Dynamic Programming:
# Task 1 - Coin Change Problem:
# Scenario: Given a set of coin denominations and a target amount, find the minimum number
# of coins needed to make the amount. If it’s not possible, return - 1.
# Task:
# 1. Write a function min_coins(coins, amount) that:
# • Uses DP to calculate the minimum number of coins needed to make up the
# amount.
# 2. Test with coins = [1, 2, 5] and amount = 11. The result should be 3 (using coins
# [5, 5, 1]).


def knapsack(weights, values, capacity):
    n = len(weights)
    dp = [[0] * (capacity + 1) for _ in range(n + 1)]
    
    for i in range(1, n + 1):
        for w in range(1, capacity + 1):
            if weights[i - 1] <= w:
                dp[i][w] = max(values[i - 1] + dp[i - 1][w - weights[i - 1]], dp[i - 1][w])
            else:
                dp[i][w] = dp[i - 1][w]
    
    return dp[n][capacity]

weights = [1, 3, 4, 5]
values = [1, 4, 5, 7]
capacity = 7
print("Maximum value:", knapsack(weights, values, capacity))
# Out:
# Maximum value: 9
